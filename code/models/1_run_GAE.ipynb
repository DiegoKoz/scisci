# %%
from tqdm.notebook import tqdm
from libs.ComputeResult import ComputeResult
import os
import pandas as pd
import re
import glob

# %%
def compute_all(text_encoding = "bert"):
    """
    run all arquitectures 10 times and save results
    text_encoding = type of encoding ["bert","tfidf","d2v"]
    """
    model_types = ["GCN","SAGE", "GIN", "GAT", "AGNN","GraphUNet"]
    for mod_type in tqdm(model_types):
        print(model_types)
        cr = ComputeResult(model_type=mod_type, text_encoding=text_encoding)
        cr.fit()

# %%
for encoding in tqdm(["bert","tfidf","d2v"]):
    compute_all(encoding)
# Out:
# ap
# 	val_ap           	 (min:    0.740, max:    0.894, cur:    0.889)
# auc
# 	val_auc          	 (min:    0.803, max:    0.881, cur:    0.877)
# EarlyStopping counter: 2 out of 100
